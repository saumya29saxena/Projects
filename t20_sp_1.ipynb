# %%
import os
import pandas as pd
from tqdm import tqdm
from yaml import safe_load

desired_path = "/content/drive/MyDrive/t20s"
os.chdir(desired_path)

directory_contents = os.listdir(desired_path)

yaml_files = [file for file in directory_contents if file.endswith('.yaml') or file.endswith('.yml')]
print(f"Number of YAML files to process: {len(yaml_files)}")

all_dataframes = []
counter = 1

for file in tqdm(yaml_files):
    full_path = os.path.join(desired_path, file)
    if os.path.exists(full_path):
        with open(full_path, 'r') as f:
            df = pd.json_normalize(safe_load(f))
            df['match_id'] = counter
            all_dataframes.append(df)
            counter += 1
    else:
        print(f"File not found: {full_path}")

final_df = pd.concat(all_dataframes, ignore_index=True)
# Out:
# Number of YAML files to process: 1432
# 100%|██████████| 1432/1432 [08:33<00:00,  2.79it/s]

# %%
backup = final_df.copy()

# %%
from IPython.display import display
display(final_df)
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 1     [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 2     [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 3     [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 4     [{'1st innings': {'team': 'England', 'deliveri...                0.9
# ...                                                 ...                ...
# 1427  [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 1428  [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 1429  [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 1430  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 1431  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
#      meta.created  meta.revision info.city    info.dates info.gender  \
# 0      2014-04-04              1    Mirpur  [2014-04-04]        male
# 1      2014-05-02              3       NaN  [2014-03-24]      female
# 2      2014-05-03              2       NaN  [2014-03-30]      female
# 3      2014-05-03              2       NaN  [2014-03-31]      female
# 4      2014-05-03              2    Mirpur  [2014-04-06]      female
# ...           ...            ...       ...           ...         ...
# 1427   2014-05-03              2       NaN  [2014-03-27]      female
# 1428   2014-05-02              2       NaN  [2014-03-25]      female
# 1429   2014-04-06              1    Mirpur  [2014-04-06]        male
# 1430   2014-05-03              3       NaN  [2014-03-28]      female
# 1431   2014-04-05              2       NaN  [2014-03-24]      female
#
#      info.match_type  info.neutral_venue  info.outcome.by.wickets  ...  \
# 0                T20                 1.0                      6.0  ...
# 1                T20                 1.0                      NaN  ...
# 2                T20                 NaN                      NaN  ...
# 3                T20                 1.0                      5.0  ...
# 4                T20                 1.0                      6.0  ...
# ...              ...                 ...                      ...  ...
# 1427             T20                 1.0                      NaN  ...
# 1428             T20                 1.0                      NaN  ...
# 1429             T20                 1.0                      6.0  ...
# 1430             T20                 1.0                      8.0  ...
# 1431             T20                 1.0                      NaN  ...
#
#      match_id  info.outcome.by.runs info.outcome.method info.outcome.result  \
# 0           1                   NaN                 NaN                 NaN
# 1           2                  22.0                 NaN                 NaN
# 2           3                  79.0                 NaN                 NaN
# 3           4                   NaN                 NaN                 NaN
# 4           5                   NaN                 NaN                 NaN
# ...       ...                   ...                 ...                 ...
# 1427     1428                  59.0                 NaN                 NaN
# 1428     1429                  42.0                 NaN                 NaN
# 1429     1430                   NaN                 NaN                 NaN
# 1430     1431                   NaN                 NaN                 NaN
# 1431     1432                   9.0                 NaN                 NaN
#
#      info.outcome.eliminator info.match_type_number  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ...                      ...                    ...
# 1427                     NaN                    NaN
# 1428                     NaN                    NaN
# 1429                     NaN                    NaN
# 1430                     NaN                    NaN
# 1431                     NaN                    NaN
#
#      info.supersubs.New Zealand info.supersubs.South Africa  info.bowl_out  \
# 0                           NaN                         NaN            NaN
# 1                           NaN                         NaN            NaN
# 2                           NaN                         NaN            NaN
# 3                           NaN                         NaN            NaN
# 4                           NaN                         NaN            NaN
# ...                         ...                         ...            ...
# 1427                        NaN                         NaN            NaN
# 1428                        NaN                         NaN            NaN
# 1429                        NaN                         NaN            NaN
# 1430                        NaN                         NaN            NaN
# 1431                        NaN                         NaN            NaN
#
#       info.outcome.bowl_out
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1427                    NaN
# 1428                    NaN
# 1429                    NaN
# 1430                    NaN
# 1431                    NaN
#
# [1432 rows x 28 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
# Out:
# <ipython-input-5-b37d11ffd314>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    963
# 50      3
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
# Out:
# <ipython-input-7-7fb4794c9448>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
from google.colab import files
files.download('dataset_level1.pkl')

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)
print(delivery_df)
# Out:
#         match_id                  teams  batting_team  ball    batsman  \
# 0              2  [India, South Africa]  South Africa   0.1  Q de Kock
# 1              2  [India, South Africa]  South Africa   0.2  Q de Kock
# 2              2  [India, South Africa]  South Africa   0.3  Q de Kock
# 3              2  [India, South Africa]  South Africa   0.4  Q de Kock
# 4              2  [India, South Africa]  South Africa   0.5  Q de Kock
# ...          ...                    ...           ...   ...        ...
# 116542       964     [India, Sri Lanka]         India  19.3   MS Dhoni
# 116543       964     [India, Sri Lanka]         India  19.4   MS Dhoni
# 116544       964     [India, Sri Lanka]         India  19.5   MS Dhoni
# 116545       964     [India, Sri Lanka]         India  19.6   MS Dhoni
# 116546       964     [India, Sri Lanka]         India  19.7    V Kohli
#
#             bowler  runs player_dismissed    city  \
# 0          B Kumar     2                0  Mirpur
# 1          B Kumar     1                0  Mirpur
# 2          B Kumar     2                0  Mirpur
# 3          B Kumar     4                0  Mirpur
# 4          B Kumar     0        Q de Kock  Mirpur
# ...            ...   ...              ...     ...
# 116542  SL Malinga     2                0  Mirpur
# 116543  SL Malinga     0                0  Mirpur
# 116544  SL Malinga     2                0  Mirpur
# 116545  SL Malinga     1                0  Mirpur
# 116546  SL Malinga     1          V Kohli  Mirpur
#
#                                 venue
# 0       Shere Bangla National Stadium
# 1       Shere Bangla National Stadium
# 2       Shere Bangla National Stadium
# 3       Shere Bangla National Stadium
# 4       Shere Bangla National Stadium
# ...                               ...
# 116542  Shere Bangla National Stadium
# 116543  Shere Bangla National Stadium
# 116544  Shere Bangla National Stadium
# 116545  Shere Bangla National Stadium
# 116546  Shere Bangla National Stadium
#
# [116547 rows x 10 columns]

# %%
from IPython.display import display
display(delivery_df)
# Out:
#         match_id                  teams  batting_team  ball    batsman  \
# 0              2  [India, South Africa]  South Africa   0.1  Q de Kock
# 1              2  [India, South Africa]  South Africa   0.2  Q de Kock
# 2              2  [India, South Africa]  South Africa   0.3  Q de Kock
# 3              2  [India, South Africa]  South Africa   0.4  Q de Kock
# 4              2  [India, South Africa]  South Africa   0.5  Q de Kock
# ...          ...                    ...           ...   ...        ...
# 116542       964     [India, Sri Lanka]         India  19.3   MS Dhoni
# 116543       964     [India, Sri Lanka]         India  19.4   MS Dhoni
# 116544       964     [India, Sri Lanka]         India  19.5   MS Dhoni
# 116545       964     [India, Sri Lanka]         India  19.6   MS Dhoni
# 116546       964     [India, Sri Lanka]         India  19.7    V Kohli
#
#             bowler  runs player_dismissed    city  \
# 0          B Kumar     2                0  Mirpur
# 1          B Kumar     1                0  Mirpur
# 2          B Kumar     2                0  Mirpur
# 3          B Kumar     4                0  Mirpur
# 4          B Kumar     0        Q de Kock  Mirpur
# ...            ...   ...              ...     ...
# 116542  SL Malinga     2                0  Mirpur
# 116543  SL Malinga     0                0  Mirpur
# 116544  SL Malinga     2                0  Mirpur
# 116545  SL Malinga     1                0  Mirpur
# 116546  SL Malinga     1          V Kohli  Mirpur
#
#                                 venue
# 0       Shere Bangla National Stadium
# 1       Shere Bangla National Stadium
# 2       Shere Bangla National Stadium
# 3       Shere Bangla National Stadium
# 4       Shere Bangla National Stadium
# ...                               ...
# 116542  Shere Bangla National Stadium
# 116543  Shere Bangla National Stadium
# 116544  Shere Bangla National Stadium
# 116545  Shere Bangla National Stadium
# 116546  Shere Bangla National Stadium
#
# [116547 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#         match_id  batting_team  ball    batsman      bowler  runs  \
# 0              2  South Africa   0.1  Q de Kock     B Kumar     2
# 1              2  South Africa   0.2  Q de Kock     B Kumar     1
# 2              2  South Africa   0.3  Q de Kock     B Kumar     2
# 3              2  South Africa   0.4  Q de Kock     B Kumar     4
# 4              2  South Africa   0.5  Q de Kock     B Kumar     0
# ...          ...           ...   ...        ...         ...   ...
# 116542       964         India  19.3   MS Dhoni  SL Malinga     2
# 116543       964         India  19.4   MS Dhoni  SL Malinga     0
# 116544       964         India  19.5   MS Dhoni  SL Malinga     2
# 116545       964         India  19.6   MS Dhoni  SL Malinga     1
# 116546       964         India  19.7    V Kohli  SL Malinga     1
#
#        player_dismissed    city                          venue bowling team
# 0                     0  Mirpur  Shere Bangla National Stadium        India
# 1                     0  Mirpur  Shere Bangla National Stadium        India
# 2                     0  Mirpur  Shere Bangla National Stadium        India
# 3                     0  Mirpur  Shere Bangla National Stadium        India
# 4             Q de Kock  Mirpur  Shere Bangla National Stadium        India
# ...                 ...     ...                            ...          ...
# 116542                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116543                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116544                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116545                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116546          V Kohli  Mirpur  Shere Bangla National Stadium    Sri Lanka
#
# [116547 rows x 10 columns]

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['South Africa', 'Bangladesh', 'West Indies', 'Sri Lanka',
#        'Pakistan', 'New Zealand', 'England', 'Australia', 'Nepal',
#        'United Arab Emirates', 'Zimbabwe', 'Afghanistan',
#        'Papua New Guinea', 'Hong Kong', 'Ireland', 'Netherlands', 'India',
#        'Oman', 'Scotland', 'Vanuatu', 'United States of America',
#        'Philippines', 'Germany', 'Uganda', 'Ghana', 'Namibia', 'Kenya',
#        'Jersey', 'Denmark', 'Norway', 'Nigeria', 'Italy', 'Botswana',
#        'Guernsey', 'Maldives', 'Thailand', 'Malaysia', 'Kuwait',
#        'Singapore', 'Cayman Islands', 'Canada', 'Bermuda', 'Gibraltar',
#        'Spain', 'Portugal', 'Bhutan', 'Iran', 'Qatar', 'Belgium',
#        'Isle of Man', 'Bulgaria', 'Romania'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id  batting_team  ball    batsman      bowler  runs  \
# 0              2  South Africa   0.1  Q de Kock     B Kumar     2
# 1              2  South Africa   0.2  Q de Kock     B Kumar     1
# 2              2  South Africa   0.3  Q de Kock     B Kumar     2
# 3              2  South Africa   0.4  Q de Kock     B Kumar     4
# 4              2  South Africa   0.5  Q de Kock     B Kumar     0
# ...          ...           ...   ...        ...         ...   ...
# 116542       964         India  19.3   MS Dhoni  SL Malinga     2
# 116543       964         India  19.4   MS Dhoni  SL Malinga     0
# 116544       964         India  19.5   MS Dhoni  SL Malinga     2
# 116545       964         India  19.6   MS Dhoni  SL Malinga     1
# 116546       964         India  19.7    V Kohli  SL Malinga     1
#
#        player_dismissed    city                          venue bowling team
# 0                     0  Mirpur  Shere Bangla National Stadium        India
# 1                     0  Mirpur  Shere Bangla National Stadium        India
# 2                     0  Mirpur  Shere Bangla National Stadium        India
# 3                     0  Mirpur  Shere Bangla National Stadium        India
# 4             Q de Kock  Mirpur  Shere Bangla National Stadium        India
# ...                 ...     ...                            ...          ...
# 116542                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116543                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116544                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116545                0  Mirpur  Shere Bangla National Stadium    Sri Lanka
# 116546          V Kohli  Mirpur  Shere Bangla National Stadium    Sri Lanka
#
# [64741 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id  batting_team bowling team  ball  runs player_dismissed  \
# 0              2  South Africa        India   0.1     2                0
# 1              2  South Africa        India   0.2     1                0
# 2              2  South Africa        India   0.3     2                0
# 3              2  South Africa        India   0.4     4                0
# 4              2  South Africa        India   0.5     0        Q de Kock
# ...          ...           ...          ...   ...   ...              ...
# 116542       964         India    Sri Lanka  19.3     2                0
# 116543       964         India    Sri Lanka  19.4     0                0
# 116544       964         India    Sri Lanka  19.5     2                0
# 116545       964         India    Sri Lanka  19.6     1                0
# 116546       964         India    Sri Lanka  19.7     1          V Kohli
#
#           city                          venue
# 0       Mirpur  Shere Bangla National Stadium
# 1       Mirpur  Shere Bangla National Stadium
# 2       Mirpur  Shere Bangla National Stadium
# 3       Mirpur  Shere Bangla National Stadium
# 4       Mirpur  Shere Bangla National Stadium
# ...        ...                            ...
# 116542  Mirpur  Shere Bangla National Stadium
# 116543  Mirpur  Shere Bangla National Stadium
# 116544  Mirpur  Shere Bangla National Stadium
# 116545  Mirpur  Shere Bangla National Stadium
# 116546  Mirpur  Shere Bangla National Stadium
#
# [64741 rows x 8 columns]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
from google.colab import files
files.download('dataset_level2.pkl')
